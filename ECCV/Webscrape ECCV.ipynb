# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
def extract_data_from_url(url, conference_year):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    data = {
        'Paper Title': [],
        'Author Names': [],
        'Author URLs': [],
        'Conference Name': 'ECCV',
        'Conference Year': conference_year
    }

    papers = soup.select('.tts-content')

    for paper in papers:
        title = paper.select_one('.title').text.strip()
        author_elements = paper.select('span[itemprop="author"]')
        links = [a['href'] for a in paper.select('a[href^="https://dblp.org/pid/"]')]

        for author_element, link in zip(author_elements, links):
            author_name = author_element.select_one('span[itemprop="name"]').text.strip()

            data['Paper Title'].append(title)
            data['Author Names'].append(author_name)
            data['Author URLs'].append(link)

    # Create a Pandas DataFrame
    df = pd.DataFrame(data)

    return df

# %%
url_conference_years = [
    ('https://dblp.org/db/conf/eccv/eccv2002-1.html', 2002),
    ('https://dblp.org/db/conf/eccv/eccv2002-2.html', 2002),
    ('https://dblp.org/db/conf/eccv/eccv2002-3.html', 2002),
    ('https://dblp.org/db/conf/eccv/eccv2002-4.html', 2002),
    ('https://dblp.org/db/conf/eccv/eccv2004-1.html', 2004),
    ('https://dblp.org/db/conf/eccv/eccv2004-2.html', 2004),
    ('https://dblp.org/db/conf/eccv/eccv2004-3.html', 2004),
    ('https://dblp.org/db/conf/eccv/eccv2004-4.html', 2004),
    ('https://dblp.org/db/conf/eccv/eccv2006-1.html', 2006),
    ('https://dblp.org/db/conf/eccv/eccv2006-2.html', 2006),
    ('https://dblp.org/db/conf/eccv/eccv2006-3.html', 2006),
    ('https://dblp.org/db/conf/eccv/eccv2006-4.html', 2006),
    ('https://dblp.org/db/conf/eccv/eccv2008-1.html', 2008),
    ('https://dblp.org/db/conf/eccv/eccv2008-2.html', 2008),
    ('https://dblp.org/db/conf/eccv/eccv2008-3.html', 2008),
    ('https://dblp.org/db/conf/eccv/eccv2008-4.html', 2008),
    ('https://dblp.org/db/conf/eccv/eccv2010-1.html', 2010),
    ('https://dblp.org/db/conf/eccv/eccv2010-2.html', 2010),
    ('https://dblp.org/db/conf/eccv/eccv2010-3.html', 2010),
    ('https://dblp.org/db/conf/eccv/eccv2010-4.html', 2010),
    ('https://dblp.org/db/conf/eccv/eccv2010-5.html', 2010),
    ('https://dblp.org/db/conf/eccv/eccv2010-6.html', 2010),
    ('https://dblp.org/db/conf/eccv/eccv2012-1.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2012-2.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2012-3.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2012-4.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2012-5.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2012-6.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2012-7.html', 2012),
    ('https://dblp.org/db/conf/eccv/eccv2014-1.html', 2014),
html', 2022),
    ('https://dblp.org/db/conf/eccv/eccv2022-38.html', 2022),
    ('https://dblp.org/db/conf/eccv/eccv2022-39.html', 2022)
]

# %%
dfs = []
for url, conference_year in url_conference_years:
    df = extract_data_from_url(url, conference_year)
    dfs.append(df)

# %%
all_eccv_data = pd.concat(dfs, ignore_index=True)
all_eccv_data
# Out:
#                                              Paper Title       Author Names  \
# 0      Computer Vision - ECCV 2002, 7th European Conf...      Anders Heyden
# 1      Computer Vision - ECCV 2002, 7th European Conf...       Gunnar Sparr
# 2      Computer Vision - ECCV 2002, 7th European Conf...       Mads Nielsen
# 3      Computer Vision - ECCV 2002, 7th European Conf...     Peter Johansen
# 4                Tracking with the EM Contour Algorithm.  Arthur E. C. Pece
# ...                                                  ...                ...
# 26380  Video Dialog as Conversation About Objects Liv...     Hoang-Anh Pham
# 26381  Video Dialog as Conversation About Objects Liv...       Thao Minh Le
# 26382  Video Dialog as Conversation About Objects Liv...           Vuong Le
# 26383  Video Dialog as Conversation About Objects Liv...     Tu Minh Phuong
# 26384  Video Dialog as Conversation About Objects Liv...        Truyen Tran
#
# ...

# %%
value_to_delete = 'Computer Vision - ECCV'
clean_eccv_data = all_eccv_data[~all_eccv_data['Paper Title'].str.contains(value_to_delete)]
clean_eccv_data
# Out:
#                                              Paper Title        Author Names  \
# 4                Tracking with the EM Contour Algorithm.   Arthur E. C. Pece
# 5                Tracking with the EM Contour Algorithm.  Anthony D. Worrall
# 6      M2Tracker: A Multi-view Approach to Segmenting...       Anurag Mittal
# 7      M2Tracker: A Multi-view Approach to Segmenting...      Larry S. Davis
# 8        Analytical Image Models and Their Applications.     Anuj Srivastava
# ...                                                  ...                 ...
# 26380  Video Dialog as Conversation About Objects Liv...      Hoang-Anh Pham
# 26381  Video Dialog as Conversation About Objects Liv...        Thao Minh Le
# 26382  Video Dialog as Conversation About Objects Liv...            Vuong Le
# 26383  Video Dialog as Conversation About Objects Liv...      Tu Minh Phuong
# 26384  Video Dialog as Conversation About Objects Liv...         Truyen Tran
#
# ...

# %%
clean_eccv_data.to_csv('eccv_paper_author.csv', index=False)

# %% [markdown]
# ## **Split Whole CSV to CSV by Year**

# %%
years = range(2002, 2024)  # Update this range based on your data

for year in years:
    if year % 2 == 0:
        year_data = clean_eccv_data[(clean_eccv_data['Conference Year'] == year)]
        
        output_file = f'eccv_data_{year}.csv'
        
        year_data.to_csv(output_file, index=False)

# %% [markdown]
# ## **Extract Author Names as JSON**

# %%
years = range(2002, 2024)

authors_per_year = {}

for year in years:
    if year % 2 == 0:
        year_data = clean_eccv_data[clean_eccv_data['Conference Year'] == year]
        
        unique_authors = year_data['Author Names'].unique()
        
        output_file = f'eccv_authors_{year}.json'
        
        json_data = [{'name': value} for value in unique_authors]
        
        with open(output_file, 'w') as json_file:
            json.dump(json_data, json_file, indent=2)
